# %% [markdown]
# # Network Operations
# ## Pre-Processing

# %%
# nuclio: ignore
import nuclio

# %% [markdown]
# Define the MLRun environment

# %%
from mlrun import new_function, code_to_function, get_run_db, mount_v3io, NewTask, mlconf, new_model_server, run_local
mlconf.dbpath = 'http://mlrun-api:8080'

# %% [markdown]
# Add used packages

# %%
# %%nuclio cmd -c
# pip install pyarrow
# pip install pandas

# %% [markdown]
# ## Function

# %%
# nuclio: start-code

# %%
import os
import pandas as pd

# %%
def aggregate(context,
              df_artifact, 
              keys=None, 
              metrics=None, 
              labels=None, 
              metric_aggs=['mean'], 
              label_aggs=['max'], 
              suffix=None, 
              window=3, 
              center=False, 
              append_to_df=True,
              save_to='aggregate_df.pq'):
    
    context.logger.info(df_artifact)
    input_df = pd.read_parquet(df_artifact)
    
    # Verify there is work to be done
    if not (metrics or labels):
        context.log_artifact('df', input_df)
        return input_df
    
    # Select the correct indexes
    if keys:
        current_index = input_df.index.names
        indexes_to_drop = [col for col in input_df.index.names if col not in keys]
        df = input_df.reset_index(level=indexes_to_drop)
    else:
        df = input_df
    
    # For each metrics
    if metrics:
        metrics_df = df.loc[:, metrics].rolling(window=window,
                                                center=center).aggregate(metric_aggs)
        
        # Flatten all the aggs
        metrics_df.columns = ['_'.join(col).strip() for col in metrics_df.columns.values]
        
        # Add suffix
        if suffix:
            metrics_df.columns = [f'{metric}_{suffix}' for metric in metrics_df.columns]
            
        if append_to_df:
            final_df = pd.merge(input_df, metrics_df, suffixes=('', suffix), left_index=True, right_index=True)
        else:
            final_df = metrics_df

    # For each label
    if labels:
        labels_df = df.loc[:, labels].rolling(window=window,
                                              center=center).aggregate(label_aggs)
        # Flatten all the aggs
        labels_df.columns = ['_'.join(col).strip() for col in labels_df.columns.values]
        
        # Add suffix
        if suffix:
            labels_df.columns = [f'{label}_{suffix}' for label in labels_df.columns]
            
        if metrics:
            final_df = pd.merge(final_df, labels_df, suffixes=('', suffix), left_index=True, right_index=True)   
        else:
            if append_to_df:
                final_df = pd.merge(input_df, labels_df, suffixes=('', suffix), left_index=True, right_index=True)      
            else:
                final_df = labels_df
        
    # Save the result dataframe
    os.makedirs(os.path.dirname(save_to), exist_ok=True)
    final_df.to_parquet(save_to, engine='pyarrow')
    context.log_artifact('aggregate', local_path=save_to)

# %%
# nuclio: end-code

# %% [markdown]
# ## Test
# Define client to get metrics sample

# %%
# Define V3IO Client
import v3io_frames as v3f
client = v3f.Client('framesd:8081', container='bigdata')

# Define base dirs
project_dir = os.path.join('/', 'User', 'demo-network-operations')

# %%
metrics = client.read('tsdb', 'netops_metrics', multi_index=True)
metrics_pq = os.path.join(project_dir, 'data', 'metrics.pq')
metrics.to_parquet(metrics_pq, engine='pyarrow', index=True)
metrics.head(2)
# Out:
#                                                                           cpu_utilization  \
# time                             company     data_center   device
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Baldwin_Views 2988452888378  87.988800
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Baldwin_Views 2988452888378  51.722187
#
#                                                                           cpu_utilization_is_error  \
# time                             company     data_center   device
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Baldwin_Views 2988452888378  0.0
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Baldwin_Views 2988452888378  0.0
#
#                                                                           is_error  \
# time                             company     data_center   device
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Baldwin_Views 2988452888378  0.0
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Baldwin_Views 2988452888378  0.0
#
#                                                                            latency  \
# time                             company     data_center   device
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Baldwin_Views 2988452888378  0.000000
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Baldwin_Views 2988452888378  7.531659
#
#                                                                           latency_is_error  \
# time                             company     data_center   device
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Baldwin_Views 2988452888378  0.0
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Baldwin_Views 2988452888378  0.0
#
#                                                                           packet_loss  \
# time                             company     data_center   device
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Baldwin_Views 2988452888378  2.318395
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Baldwin_Views 2988452888378  0.194195
#
#                                                                           packet_loss_is_error  \
# time                             company     data_center   device
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Baldwin_Views 2988452888378  0.0
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Baldwin_Views 2988452888378  0.0
#
#                                                                           throughput  \
# time                             company     data_center   device
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Baldwin_Views 2988452888378  225.476913
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Baldwin_Views 2988452888378  247.212094
#
#                                                                           throughput_is_error
# time                             company     data_center   device
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Baldwin_Views 2988452888378  0.0
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Baldwin_Views 2988452888378  0.0

# %% [markdown]
# ### Local Test
# Define the aggregate test task

# %%
aggregate_task = NewTask(name='aggregate',
                         project='network-operations',
                         params={'df_artifact': os.path.join(project_dir, 'data', 'metrics.pq'),
                                 'metrics': ['cpu_utilization'],
                                 'labels': ['is_error'],
                                 'metric_aggs': ['mean', 'sum'],
                                 'label_aggs': ['max'],
                                 'suffix': 'daily',
                                 'append_to_df': True,
                                 'window': 5,
                                 'center': True,
                                 'save_to': os.path.join(project_dir, 'data', 'aggregate.pq')},
                         handler=aggregate)

# %%
run_local(aggregate_task)
# Out:
# [mlrun] 2020-03-10 08:54:32,345 starting run aggregate uid=ae0380d6717849a79ae8f7202f6b500f  -> http://mlrun-api:8080
# [mlrun] 2020-03-10 08:54:32,371 /User/demo-network-operations/data/metrics.pq
# [mlrun] 2020-03-10 08:54:32,421 log artifact aggregate at /User/demo-network-operations/data/aggregate.pq, size: 18131, db: Y
# <style>
# .dictlist {
#   background-color: #b3edff;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #ffe6cc;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #ffe6cc;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><div title="ae0380d6717849a79ae8f7202f6b500f">...6b500f</div></td>
#       <td>0</td>
#       <td>Mar 10 08:54:32</td>
#       <td>completed</td>
#       <td>aggregate</td>
#       <td><div class="dictlist">kind=handler</div><div class="dictlist">owner=admin</div><div class="dictlist">host=jupyter-78ddb8b99c-mz8dk</div></td>
#       <td></td>
#       <td><div class="dictlist">df_artifact=/User/demo-network-operations/data/metrics.pq</div><div class="dictlist">metrics=['cpu_utilization']</div><div class="dictlist">labels=['is_error']</div><div class="dictlist">metric_aggs=['mean', 'sum']</div><div class="dictlist">label_aggs=['max']</div><div class="dictlist">suffix=daily</div><div class="dictlist">append_to_df=True</div><div class="dictlist">window=5</div><div class="dictlist">center=True</div><div class="dictlist">save_to=/User/demo-network-operations/data/aggregate.pq</div></td>
#       <td></td>
#       <td><div title="/User/demo-network-operations/data/aggregate.pq">aggregate</div></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="result3c99bffa-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="result3c99bffa-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="result3c99bffa" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="result3c99bffa-body"></iframe>
#   </div>
# </div>
# to track results use .show() or .logs() or in CLI:
# !mlrun get run ae0380d6717849a79ae8f7202f6b500f --project network-operations , !mlrun logs ae0380d6717849a79ae8f7202f6b500f --project network-operations
# [mlrun] 2020-03-10 08:54:32,449 run executed, status=completed

# %% [markdown]
# ### Test on cluster

# %% [markdown]
# Convert the code to an MLRun function

# %%
fn = code_to_function('aggregate', 
                      code_output=os.path.join(project_dir, 'src', 'aggregate.py'),
                      kind='job').apply(mount_v3io())

# %%
fn.deploy()
# Out:
# [mlrun] 2020-03-10 08:45:58,390 starting remote build, image: .mlrun/func-default-aggregate-latest
# INFO[0000] Resolved base name mlrun/mlrun:0.4.4 to mlrun/mlrun:0.4.4
# INFO[0000] Resolved base name mlrun/mlrun:0.4.4 to mlrun/mlrun:0.4.4
# INFO[0000] Downloading base image mlrun/mlrun:0.4.4
# INFO[0000] Error while retrieving image from cache: getting file info: stat /cache/sha256:6acdce89d632b5e683a6d7fa651a928ba2227f7322060d207491518dd555543c: no such file or directory
# INFO[0000] Downloading base image mlrun/mlrun:0.4.4
# INFO[0000] Built cross stage deps: map[]
# INFO[0000] Downloading base image mlrun/mlrun:0.4.4
# INFO[0000] Error while retrieving image from cache: getting file info: stat /cache/sha256:6acdce89d632b5e683a6d7fa651a928ba2227f7322060d207491518dd555543c: no such file or directory
# INFO[0000] Downloading base image mlrun/mlrun:0.4.4
# INFO[0000] Unpacking rootfs as cmd RUN pip install pyarrow requires it.
# INFO[0022] Taking snapshot of full filesystem...
# INFO[0039] RUN pip install pyarrow
# INFO[0039] cmd: /bin/sh
# INFO[0039] args: [-c pip install pyarrow]
# Collecting pyarrow
#   Downloading https://files.pythonhosted.org/packages/c3/0b/f5d91e83fcf025856f43d95d477efdf8839dbd9186153f571aa9901c882b/pyarrow-0.16.0-cp36-cp36m-manylinux2010_x86_64.whl (63.7MB)
# Requirement already satisfied: six>=1.0.0 in /usr/local/lib/python3.6/site-packages (from pyarrow) (1.14.0)
# Requirement already satisfied: numpy>=1.14 in /usr/local/lib/python3.6/site-packages (from pyarrow) (1.18.1)
# Installing collected packages: pyarrow
# Successfully installed pyarrow-0.16.0
# WARNING: You are using pip version 19.2.3, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# INFO[0044] Taking snapshot of full filesystem...
# INFO[0053] RUN pip install pandas
# INFO[0053] cmd: /bin/sh
# INFO[0053] args: [-c pip install pandas]
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/site-packages (0.25.3)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/site-packages (from pandas) (2019.3)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/site-packages (from pandas) (1.18.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/site-packages (from python-dateutil>=2.6.1->pandas) (1.14.0)
# WARNING: You are using pip version 19.2.3, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# INFO[0054] Taking snapshot of full filesystem...
# True

# %%
fn.run(aggregate_task)
# Out:
# [mlrun] 2020-03-10 08:54:41,476 starting run aggregate uid=6c065c9d39b14b7f839a0ffe8e177894  -> http://mlrun-api:8080
# [mlrun] 2020-03-10 08:54:41,530 Job is running in the background, pod: aggregate-jmght
# [mlrun] 2020-03-10 08:54:46,243 /User/demo-network-operations/data/metrics.pq
# [mlrun] 2020-03-10 08:54:46,339 log artifact aggregate at /User/demo-network-operations/data/aggregate.pq, size: 18131, db: Y
#
# [mlrun] 2020-03-10 08:54:46,349 run executed, status=completed
# final state: succeeded
# <style>
# .dictlist {
#   background-color: #b3edff;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #ffe6cc;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #ffe6cc;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><div title="6c065c9d39b14b7f839a0ffe8e177894">...177894</div></td>
#       <td>0</td>
#       <td>Mar 10 08:54:46</td>
#       <td>completed</td>
#       <td>aggregate</td>
#       <td><div class="dictlist">host=aggregate-jmght</div><div class="dictlist">kind=job</div><div class="dictlist">owner=admin</div></td>
#       <td></td>
#       <td><div class="dictlist">append_to_df=True</div><div class="dictlist">center=True</div><div class="dictlist">df_artifact=/User/demo-network-operations/data/metrics.pq</div><div class="dictlist">label_aggs=['max']</div><div class="dictlist">labels=['is_error']</div><div class="dictlist">metric_aggs=['mean', 'sum']</div><div class="dictlist">metrics=['cpu_utilization']</div><div class="dictlist">save_to=/User/demo-network-operations/data/aggregate.pq</div><div class="dictlist">suffix=daily</div><div class="dictlist">window=5</div></td>
#       <td></td>
#       <td><div title="/User/demo-network-operations/data/aggregate.pq">aggregate</div></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="result7244eeb0-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="result7244eeb0-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="result7244eeb0" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="result7244eeb0-body"></iframe>
#   </div>
# </div>
# to track results use .show() or .logs() or in CLI:
# !mlrun get run 6c065c9d39b14b7f839a0ffe8e177894 --project network-operations , !mlrun logs 6c065c9d39b14b7f839a0ffe8e177894 --project network-operations
# [mlrun] 2020-03-10 08:54:47,638 run executed, status=completed

# %% [markdown]
# ### Show results

# %%
pd.read_parquet(os.path.join(project_dir, 'data', 'aggregate.pq'))
# Out:
#                                                                             cpu_utilization  \
# time                             company     data_center     device
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  87.988800
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  51.722187
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  80.521866
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  68.418494
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  62.507122
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  74.290277
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  73.027303
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  76.652209
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  64.215970
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  76.249996
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  69.285541
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  69.830719
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  62.579074
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  71.902650
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  63.602907
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  73.296864
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  72.330401
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  67.045086
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  69.152779
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  60.570721
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  75.712559
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  48.449794
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  57.769840
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  61.553683
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  71.893658
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  77.145593
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  79.751056
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  52.945932
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  72.793073
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  64.785601
# ...                                                                               ...
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  76.610135
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  72.281656
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  62.651041
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  72.332165
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  79.545793
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  76.778279
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  76.670879
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  60.883057
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  63.117712
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  84.303129
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  63.379474
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  58.995820
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  67.729800
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  72.175691
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  71.947311
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  61.268848
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  88.216498
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  79.389182
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  76.063980
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  86.334071
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  65.234329
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  68.055215
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  62.295093
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  51.960499
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  69.733993
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  77.388499
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  68.032051
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  70.780619
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  70.525980
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  62.514011
#
#                                                                             cpu_utilization_is_error  \
# time                             company     data_center     device
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# ...                                                                         ...
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
#
#                                                                             is_error  \
# time                             company     data_center     device
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# ...                                                                         ...
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
#
#                                                                               latency  \
# time                             company     data_center     device
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.000000
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  7.531659
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.000000
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  4.965965
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.000000
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.000000
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  1.352214
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  4.090376
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.000000
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.623090
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.000000
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  1.306432
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.483996
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.000000
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.000000
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.000000
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  3.070309
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  2.379906
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  1.445033
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.000000
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.000000
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.000000
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  9.521581
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.000000
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.000000
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  6.459275
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.000000
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  2.263769
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  1.219511
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  14.751666
# ...                                                                              ...
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.000000
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.000000
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  1.510624
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.000000
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  7.451084
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  1.449486
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.000000
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.000000
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.271292
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.000000
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.176216
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  2.549024
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.000000
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.000000
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.289907
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  4.824502
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  4.738152
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.000000
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  1.440378
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.000000
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  4.635859
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  5.329582
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.347865
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  5.158927
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.345904
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  1.936971
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.898516
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  2.410296
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  1.370329
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.000000
#
#                                                                             latency_is_error  \
# time                             company     data_center     device
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# ...                                                                         ...
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
#
#                                                                             packet_loss  \
# time                             company     data_center     device
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  2.318395
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.194195
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  3.215264
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.000000
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.000000
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.000000
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  2.406516
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.000000
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.835418
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.000000
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.000000
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.901916
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.000000
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.000000
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.903911
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.001877
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.000000
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  3.345860
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  2.307934
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.416599
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.483724
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  3.371950
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  1.715123
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  1.380904
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.241342
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  3.761707
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.145718
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.000000
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.000000
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.425465
# ...                                                                              ...
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.000000
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.986051
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.000000
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.000000
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  2.573838
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.000000
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.000000
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.000000
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.000000
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.382823
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  1.009329
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  1.200767
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.125743
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.262237
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.000000
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.000000
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  1.278037
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.000000
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  1.259072
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.212553
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  1.335424
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  3.808366
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.000000
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.000000
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.000000
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.000000
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.270415
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.000000
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.000000
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.000000
#
#                                                                             packet_loss_is_error  \
# time                             company     data_center     device
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# ...                                                                         ...
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
#
#                                                                             throughput  \
# time                             company     data_center     device
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  225.476913
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  247.212094
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  256.570104
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  236.683272
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  236.058218
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  230.421777
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  233.408268
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  265.515381
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  281.644191
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  240.905564
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  243.452722
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  230.057116
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  234.880985
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  237.221853
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  236.614697
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  245.300766
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  222.870818
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  240.734272
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  230.828092
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  261.635647
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  231.970215
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  234.276311
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  236.091618
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  227.398276
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  256.287040
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  231.609140
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  239.112236
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  218.979856
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  232.764105
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  254.653725
# ...                                                                                ...
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  259.501856
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  261.717568
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  240.244157
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  262.342103
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  267.269320
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  252.502050
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  269.934712
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  257.128160
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  238.024951
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  225.632938
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  245.948293
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  241.466831
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  246.427762
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  266.514884
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  185.687564
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  269.104190
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  244.831516
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  292.547987
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  281.529194
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  254.995247
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  250.693610
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  265.629411
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  240.431691
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  280.730696
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  211.036808
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  286.585066
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  254.105100
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  258.014070
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  222.321235
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  259.380771
#
#                                                                             throughput_is_error  \
# time                             company     data_center     device
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# ...
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  68.952623
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  70.784394
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  72.684158
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  72.717787
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  73.595631
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  73.242035
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  71.399144
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  72.350611
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  69.670850
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  66.135839
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  67.505187
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  69.316783
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  66.845619
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  66.423494
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  72.267630
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  74.599506
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  75.377164
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  78.254516
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  79.047612
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  75.015356
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  71.596538
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  66.775841
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  63.455826
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  65.886660
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  65.882027
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  67.579132
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  71.292228
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  69.848232
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931 NaN
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931 NaN
#
#                                                                             cpu_utilization_sum_daily  \
# time                             company     data_center     device
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378 NaN
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378 NaN
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  351.158469
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  337.459946
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  358.765062
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  354.895404
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  350.692880
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  364.435755
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  359.431019
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  356.234435
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  342.161300
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  349.847980
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  337.200891
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  341.212214
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  343.711896
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  348.177908
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  345.428037
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  342.395851
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  344.811546
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  320.930940
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  311.655694
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  304.056598
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  315.379535
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  316.812569
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  348.113831
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  343.289923
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  354.529312
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  347.421255
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  344.861177
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  347.734086
# ...                                                                                ...
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  344.763116
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  353.921968
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  363.420789
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  363.588934
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  367.978157
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  366.210173
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  356.995721
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  361.753057
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  348.354251
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  330.679193
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  337.525936
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  346.583915
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  334.228097
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  332.117471
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  361.338148
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  372.997530
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  376.885819
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  391.272579
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  395.238061
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  375.076778
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  357.982688
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  333.879207
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  317.279128
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  329.433298
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  329.410134
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  337.895661
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  356.461142
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  349.241160
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931 NaN
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931 NaN
#
#                                                                             is_error_max_daily
# time                             company     data_center     device
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378 NaN
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378 NaN
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Baldwin_Views   2988452888378  0.0
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Baldwin_Views   1456313469721  0.0
# ...                                                                         ...
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Chelsey_Terrace 4587130103799  0.0
# 2020-03-10 08:52:37.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:52:42.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:52:47.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:52:52.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:52:57.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:02.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:07.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:12.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:17.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:22.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:27.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:32.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:37.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:42.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931  0.0
# 2020-03-10 08:53:47.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931 NaN
# 2020-03-10 08:53:52.874000+00:00 Elliott_Inc Chelsey_Terrace 8491245000931 NaN
#
# [128 rows x 12 columns]
