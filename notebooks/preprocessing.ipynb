# %% [markdown]
# # Network Operations
# ## Pre-Processing

# %%
# nuclio: ignore
import nuclio

# %% [markdown]
# Define the MLRun environment

# %%
from mlrun import new_function, code_to_function, get_run_db, mount_v3io, NewTask, mlconf, new_model_server, run_local
mlconf.dbpath = 'http://mlrun-api:8080'

# %% [markdown]
# Add used packages

# %%
# %%nuclio cmd -c
# pip install pyarrow
# pip install pandas

# %% [markdown]
# ## Function

# %%
# nuclio: start-code

# %%
import os
import pandas as pd

# %%
def aggregate(context,
              df_artifact, 
              keys=None, 
              metrics=None, 
              labels=None, 
              metric_aggs=['mean'], 
              label_aggs=['max'], 
              suffix=None, 
              window=3, 
              center=False, 
              append_to_df=True,
              save_to='aggregate_df.pq'):
    
    context.logger.info(df_artifact)
    input_df = pd.read_parquet(df_artifact)
    
    # Verify there is work to be done
    if not (metrics or labels):
        context.log_artifact('df', input_df)
        return input_df
    
    # Select the correct indexes
    if keys:
        current_index = input_df.index.names
        indexes_to_drop = [col for col in input_df.index.names if col not in keys]
        df = input_df.reset_index(level=indexes_to_drop)
    else:
        df = input_df
    
    # For each metrics
    if metrics:
        metrics_df = df.loc[:, metrics].rolling(window=window,
                                                center=center).aggregate(metric_aggs)
        
        # Flatten all the aggs
        metrics_df.columns = ['_'.join(col).strip() for col in metrics_df.columns.values]
        
        # Add suffix
        if suffix:
            metrics_df.columns = [f'{metric}_{suffix}' for metric in metrics_df.columns]
            
        if append_to_df:
            final_df = pd.merge(input_df, metrics_df, suffixes=('', suffix), left_index=True, right_index=True)
        else:
            final_df = metrics_df

    # For each label
    if labels:
        labels_df = df.loc[:, labels].rolling(window=window,
                                              center=center).aggregate(label_aggs)
        # Flatten all the aggs
        labels_df.columns = ['_'.join(col).strip() for col in labels_df.columns.values]
        
        # Add suffix
        if suffix:
            labels_df.columns = [f'{label}_{suffix}' for label in labels_df.columns]
            
        if metrics:
            final_df = pd.merge(final_df, labels_df, suffixes=('', suffix), left_index=True, right_index=True)   
        else:
            if append_to_df:
                final_df = pd.merge(input_df, labels_df, suffixes=('', suffix), left_index=True, right_index=True)      
            else:
                final_df = labels_df
        
    # Save the result dataframe
    os.makedirs(os.path.dirname(save_to), exist_ok=True)
    final_df.to_parquet(save_to, engine='pyarrow')
    context.log_artifact('aggregate', local_path=save_to)

# %%
# nuclio: end-code

# %% [markdown]
# ## Test
# Define client to get metrics sample

# %%
# Define V3IO Client
import v3io_frames as v3f
client = v3f.Client('framesd:8081', container='bigdata')

# Define base dirs
project_dir = os.path.join('/', 'User', 'demo-network-operations')

# %%
metrics = client.read('tsdb', 'netops_metrics', multi_index=True)
metrics_pq = os.path.join(project_dir, 'data', 'metrics.pq')
metrics.to_parquet(metrics_pq, engine='pyarrow', index=True)
metrics.head(2)
# Out:
#                                                                                         cpu_utilization  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526        78.396905
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526        73.343463
#
#                                                                                         cpu_utilization_is_error  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                       0.0
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                       0.0
#
#                                                                                         is_error  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526       0.0
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526       0.0
#
#                                                                                         latency  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526      0.0
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526      0.0
#
#                                                                                         latency_is_error  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526               0.0
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526               0.0
#
#                                                                                         packet_loss  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526     0.000000
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526     0.113283
#
#                                                                                         packet_loss_is_error  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                   0.0
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                   0.0
#
#                                                                                         throughput  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  251.553131
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  247.769434
#
#                                                                                         throughput_is_error
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                  0.0
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                  0.0

# %% [markdown]
# ### Local Test
# Define the aggregate test task

# %%
aggregate_task = NewTask(name='aggregate',
                         project='network-operations',
                         params={'df_artifact': os.path.join(project_dir, 'data', 'metrics.pq'),
                                 'metrics': ['cpu_utilization'],
                                 'labels': ['is_error'],
                                 'metric_aggs': ['mean', 'sum'],
                                 'label_aggs': ['max'],
                                 'suffix': 'daily',
                                 'append_to_df': True,
                                 'window': 5,
                                 'center': True,
                                 'save_to': os.path.join(project_dir, 'data', 'aggregate.pq')},
                         handler=aggregate)

# %%
run_local(aggregate_task)
# Out:
# [mlrun] 2020-03-10 08:58:23,186 starting run aggregate uid=d29be7a9c96848fbbe814df748592033  -> http://mlrun-api:8080
# [mlrun] 2020-03-10 08:58:23,214 /User/demo-network-operations/data/metrics.pq
# [mlrun] 2020-03-10 08:58:23,286 log artifact aggregate at /User/demo-network-operations/data/aggregate.pq, size: 37175, db: Y
# <style>
# .dictlist {
#   background-color: #b3edff;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #ffe6cc;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #ffe6cc;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><div title="d29be7a9c96848fbbe814df748592033">...592033</div></td>
#       <td>0</td>
#       <td>Mar 10 08:58:23</td>
#       <td>completed</td>
#       <td>aggregate</td>
#       <td><div class="dictlist">kind=handler</div><div class="dictlist">owner=admin</div><div class="dictlist">host=jupyter-78ddb8b99c-mz8dk</div></td>
#       <td></td>
#       <td><div class="dictlist">df_artifact=/User/demo-network-operations/data/metrics.pq</div><div class="dictlist">metrics=['cpu_utilization']</div><div class="dictlist">labels=['is_error']</div><div class="dictlist">metric_aggs=['mean', 'sum']</div><div class="dictlist">label_aggs=['max']</div><div class="dictlist">suffix=daily</div><div class="dictlist">append_to_df=True</div><div class="dictlist">window=5</div><div class="dictlist">center=True</div><div class="dictlist">save_to=/User/demo-network-operations/data/aggregate.pq</div></td>
#       <td></td>
#       <td><div title="/User/demo-network-operations/data/aggregate.pq">aggregate</div></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="result5cfed6a7-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="result5cfed6a7-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="result5cfed6a7" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="result5cfed6a7-body"></iframe>
#   </div>
# </div>
# to track results use .show() or .logs() or in CLI:
# !mlrun get run d29be7a9c96848fbbe814df748592033 --project network-operations , !mlrun logs d29be7a9c96848fbbe814df748592033 --project network-operations
# [mlrun] 2020-03-10 08:58:23,320 run executed, status=completed

# %% [markdown]
# ### Test on cluster

# %% [markdown]
# Convert the code to an MLRun function

# %%
fn = code_to_function('aggregate', 
                      code_output=os.path.join(project_dir, 'src', 'aggregate.py'),
                      kind='job').apply(mount_v3io())
fn.export(os.path.join(project_dir, 'yaml', 'aggregate.yaml'))
# Out:
# [mlrun] 2020-03-10 08:58:28,305 function spec saved to path: /User/demo-network-operations/yaml/aggregate.yaml

# %%
fn.deploy()
# Out:
# [mlrun] 2020-03-10 08:58:28,328 starting remote build, image: .mlrun/func-default-aggregate-latest
# INFO[0000] Resolved base name mlrun/mlrun:0.4.4 to mlrun/mlrun:0.4.4
# INFO[0000] Resolved base name mlrun/mlrun:0.4.4 to mlrun/mlrun:0.4.4
# INFO[0000] Downloading base image mlrun/mlrun:0.4.4
# INFO[0000] Error while retrieving image from cache: getting file info: stat /cache/sha256:6acdce89d632b5e683a6d7fa651a928ba2227f7322060d207491518dd555543c: no such file or directory
# INFO[0000] Downloading base image mlrun/mlrun:0.4.4
# INFO[0000] Built cross stage deps: map[]
# INFO[0000] Downloading base image mlrun/mlrun:0.4.4
# INFO[0000] Error while retrieving image from cache: getting file info: stat /cache/sha256:6acdce89d632b5e683a6d7fa651a928ba2227f7322060d207491518dd555543c: no such file or directory
# INFO[0000] Downloading base image mlrun/mlrun:0.4.4
# INFO[0000] Unpacking rootfs as cmd RUN pip install pyarrow requires it.
# INFO[0020] Taking snapshot of full filesystem...
# INFO[0032] RUN pip install pyarrow
# INFO[0032] cmd: /bin/sh
# INFO[0032] args: [-c pip install pyarrow]
# Collecting pyarrow
#   Downloading https://files.pythonhosted.org/packages/c3/0b/f5d91e83fcf025856f43d95d477efdf8839dbd9186153f571aa9901c882b/pyarrow-0.16.0-cp36-cp36m-manylinux2010_x86_64.whl (63.7MB)
# Requirement already satisfied: numpy>=1.14 in /usr/local/lib/python3.6/site-packages (from pyarrow) (1.18.1)
# Requirement already satisfied: six>=1.0.0 in /usr/local/lib/python3.6/site-packages (from pyarrow) (1.14.0)
# Installing collected packages: pyarrow
# Successfully installed pyarrow-0.16.0
# WARNING: You are using pip version 19.2.3, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# INFO[0037] Taking snapshot of full filesystem...
# INFO[0045] RUN pip install pandas
# INFO[0045] cmd: /bin/sh
# INFO[0045] args: [-c pip install pandas]
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/site-packages (0.25.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/site-packages (from pandas) (1.18.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/site-packages (from pandas) (2019.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/site-packages (from python-dateutil>=2.6.1->pandas) (1.14.0)
# WARNING: You are using pip version 19.2.3, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# INFO[0046] Taking snapshot of full filesystem...
# True

# %%
fn.run(aggregate_task)
# Out:
# [mlrun] 2020-03-10 08:59:31,507 starting run aggregate uid=0dd33c2630f548a99095586049574fae  -> http://mlrun-api:8080
# [mlrun] 2020-03-10 08:59:31,559 Job is running in the background, pod: aggregate-wfb9n
# [mlrun] 2020-03-10 08:59:39,064 /User/demo-network-operations/data/metrics.pq
# [mlrun] 2020-03-10 08:59:39,152 log artifact aggregate at /User/demo-network-operations/data/aggregate.pq, size: 37175, db: Y
#
# [mlrun] 2020-03-10 08:59:39,162 run executed, status=completed
# final state: succeeded
# <style>
# .dictlist {
#   background-color: #b3edff;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #ffe6cc;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #ffe6cc;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><div title="0dd33c2630f548a99095586049574fae">...574fae</div></td>
#       <td>0</td>
#       <td>Mar 10 08:59:39</td>
#       <td>completed</td>
#       <td>aggregate</td>
#       <td><div class="dictlist">host=aggregate-wfb9n</div><div class="dictlist">kind=job</div><div class="dictlist">owner=admin</div></td>
#       <td></td>
#       <td><div class="dictlist">append_to_df=True</div><div class="dictlist">center=True</div><div class="dictlist">df_artifact=/User/demo-network-operations/data/metrics.pq</div><div class="dictlist">label_aggs=['max']</div><div class="dictlist">labels=['is_error']</div><div class="dictlist">metric_aggs=['mean', 'sum']</div><div class="dictlist">metrics=['cpu_utilization']</div><div class="dictlist">save_to=/User/demo-network-operations/data/aggregate.pq</div><div class="dictlist">suffix=daily</div><div class="dictlist">window=5</div></td>
#       <td></td>
#       <td><div title="/User/demo-network-operations/data/aggregate.pq">aggregate</div></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="resultb4e96fd5-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="resultb4e96fd5-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="resultb4e96fd5" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="resultb4e96fd5-body"></iframe>
#   </div>
# </div>
# to track results use .show() or .logs() or in CLI:
# !mlrun get run 0dd33c2630f548a99095586049574fae --project network-operations , !mlrun logs 0dd33c2630f548a99095586049574fae --project network-operations
# [mlrun] 2020-03-10 08:59:40,704 run executed, status=completed

# %% [markdown]
# ### Show results

# %%
pd.read_parquet(os.path.join(project_dir, 'data', 'aggregate.pq'))
# Out:
#                                                                                         cpu_utilization  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  78.396905
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  73.343463
# 2020-03-10 08:52:47.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  59.492871
# 2020-03-10 08:52:52.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  73.483893
# 2020-03-10 08:52:57.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  70.904103
# 2020-03-10 08:53:02.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  82.890184
# 2020-03-10 08:53:07.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  97.284105
# 2020-03-10 08:53:12.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  67.758731
# 2020-03-10 08:53:17.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  53.616354
# 2020-03-10 08:53:22.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  73.430648
# 2020-03-10 08:53:27.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  67.135130
# 2020-03-10 08:53:32.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  66.689955
# 2020-03-10 08:53:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  64.666766
# 2020-03-10 08:53:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  57.830606
# 2020-03-10 08:53:47.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  65.375172
# 2020-03-10 08:53:52.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  49.134027
# 2020-03-10 08:53:57.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  95.108009
# 2020-03-10 08:54:02.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  69.434510
# 2020-03-10 08:54:07.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  52.724959
# 2020-03-10 08:54:12.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526