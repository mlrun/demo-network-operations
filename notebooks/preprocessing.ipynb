# %% [markdown]
# # Network Operations
# ## Pre-Processing

# %%
# nuclio: ignore
import nuclio

# %% [markdown]
# Define the MLRun environment

# %%
from mlrun import new_function, code_to_function, get_run_db, mount_v3io, NewTask, mlconf, new_model_server, run_local
mlconf.dbpath = 'http://mlrun-api:8080'

# %%
# %nuclio config kind = "job"

# %% [markdown]
# ## Function

# %%
# nuclio: start-code

# %%
import os
import pandas as pd

# %%
def aggregate(context,
              df_artifact, 
              keys=None, 
              metrics=None, 
              labels=None, 
              metric_aggs=['mean'], 
              label_aggs=['max'], 
              suffix=None, 
              window=3, 
              center=False, 
              inplace=False):
    
    context.logger.info(df_artifact)
    input_df = pd.read_parquet(df_artifact)
    
    # Verify there is work to be done
    if not (metrics or labels):
        context.log_artifact('df', input_df)
        return input_df
    
    # Select the correct indexes
    if keys:
        current_index = input_df.index.names
        indexes_to_drop = [col for col in input_df.index.names if col not in keys]
        df = input_df.reset_index(level=indexes_to_drop)
    else:
        df = input_df
    
    # For each metrics
    if metrics:
        metrics_df = df.loc[:, metrics].rolling(window=window,
                                                center=center).aggregate(metric_aggs)
        
        # Flatten all the aggs
        metrics_df.columns = ['_'.join(col).strip() for col in metrics_df.columns.values]
        
        # Add suffix
        if suffix:
            metrics_df.columns = [f'{metric}_{suffix}' for metric in metrics_df.columns]
            
        if append_to_df:
            final_df = pd.merge(input_df, metrics_df, suffixes=('', suffix), left_index=True, right_index=True)
        else:
            final_df = metrics_df

    # For each label
    if labels:
        labels_df = df.loc[:, labels].rolling(window=window,
                                              center=center).aggregate(label_aggs)
        # Flatten all the aggs
        labels_df.columns = ['_'.join(col).strip() for col in labels_df.columns.values]
        
        # Add suffix
        if suffix:
            labels_df.columns = [f'{label}_{suffix}' for label in labels_df.columns]
            
        if metrics:
            final_df = pd.merge(final_df, labels_df, suffixes=('', suffix), left_index=True, right_index=True)   
        else:
            if append_to_df:
                final_df = pd.merge(input_df, labels_df, suffixes=('', suffix), left_index=True, right_index=True)      
            else:
                final_df = labels_df
        
    # Save the result dataframe
    # TODO: Change to log_datset
    context.log_dataset(key='aggregate', 
                        df=final_df, 
                        format='parquet')

# %%
# nuclio: end-code

# %% [markdown]
# ## Test
# Define client to get metrics sample

# %%
# Define V3IO Client
import v3io_frames as v3f
client = v3f.Client('framesd:8081', container='bigdata')

# Define base dirs
project_dir = os.path.join('/', 'User', 'demo-network-operations')

# %%
metrics = client.read('tsdb', 'netops_metrics', multi_index=True)
metrics_pq = os.path.join(project_dir, 'data', 'metrics.pq')
metrics.to_parquet(metrics_pq, engine='pyarrow', index=True)
metrics.head(2)
# Out:
#                                                                                         cpu_utilization  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526        78.396905
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526        73.343463
#
#                                                                                         cpu_utilization_is_error  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                       0.0
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                       0.0
#
#                                                                                         is_error  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526       0.0
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526       0.0
#
#                                                                                         latency  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526      0.0
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526      0.0
#
#                                                                                         latency_is_error  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526               0.0
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526               0.0
#
#                                                                                         packet_loss  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526     0.000000
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526     0.113283
#
#                                                                                         packet_loss_is_error  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                   0.0
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                   0.0
#
#                                                                                         throughput  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  251.553131
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  247.769434
#
#                                                                                         throughput_is_error
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                  0.0
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                  0.0

# %% [markdown]
# ### Local Test
# Define the aggregate test task

# %%
aggregate_task = NewTask(name='aggregate',
                         project='network-operations',
                         params={'df_artifact': os.path.join(project_dir, 'data', 'metrics.pq'),
                                 'metrics': ['cpu_utilization'],
                                 'labels': ['is_error'],
                                 'metric_aggs': ['mean', 'sum'],
                                 'label_aggs': ['max'],
                                 'suffix': 'daily',
                                 'inplace': False,
                                 'window': 5,
                                 'center': True},
                         handler=aggregate)

# %% [markdown]
# rolling(window, ....)
# aggregate([])
# {
#     'aggregate': [<cols>],
# }
#
# Join([.....], )
# {
#
# }
#
# Operators_fun(
# -- Load data
# -- Functions
#  [
#      {'aggregate': {'cols': 'agg'}},
#      {'save_dataset': {'to': '....'}},
#      {'join': [previous_step.outputs['data'], static_data_1]},
#      {'aggregate': {'cols': 'agg'}},
#  ]
# )

# %%
run_local(aggregate_task)
# Out:
# [mlrun] 2020-03-12 15:31:27,423 artifact path is not defined or is local,artifacts will not be visible in the UI
# [mlrun] 2020-03-12 15:31:27,431 warning!, server (0.4.5) and client (0.4.6) ver dont match
# [mlrun] 2020-03-12 15:31:27,431 starting run aggregate uid=d0e64ae914ae480aaf22cf9665b185e3  -> http://mlrun-api:8080
# [mlrun] 2020-03-12 15:31:27,448 warning!, server (0.4.5) and client (0.4.6) ver dont match
# [mlrun] 2020-03-12 15:31:27,458 /User/demo-network-operations/data/metrics.pq
# [mlrun] 2020-03-12 15:31:27,724 log artifact aggregate at /User/demo-network-operations/data/aggregate.pq, size: 37174, db: Y
# <style>
# .dictlist {
#   background-color: #b3edff;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #ffe6cc;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #ffe6cc;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><div title="d0e64ae914ae480aaf22cf9665b185e3">...b185e3</div></td>
#       <td>0</td>
#       <td>Mar 12 15:31:27</td>
#       <td>completed</td>
#       <td>aggregate</td>
#       <td><div class="dictlist">kind=handler</div><div class="dictlist">owner=admin</div><div class="dictlist">host=jupyter-78ddb8b99c-rpmd7</div></td>
#       <td></td>
#       <td><div class="dictlist">df_artifact=/User/demo-network-operations/data/metrics.pq</div><div class="dictlist">metrics=['cpu_utilization']</div><div class="dictlist">labels=['is_error']</div><div class="dictlist">metric_aggs=['mean', 'sum']</div><div class="dictlist">label_aggs=['max']</div><div class="dictlist">suffix=daily</div><div class="dictlist">append_to_df=True</div><div class="dictlist">window=5</div><div class="dictlist">center=True</div><div class="dictlist">save_to=/User/demo-network-operations/data/aggregate.pq</div></td>
#       <td></td>
#       <td><div title="/User/demo-network-operations/data/aggregate.pq">aggregate</div></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="result331f834b-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="result331f834b-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="result331f834b" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="result331f834b-body"></iframe>
#   </div>
# </div>
# to track results use .show() or .logs() or in CLI:
# !mlrun get run d0e64ae914ae480aaf22cf9665b185e3 --project network-operations , !mlrun logs d0e64ae914ae480aaf22cf9665b185e3 --project network-operations
# [mlrun] 2020-03-12 15:31:27,779 run executed, status=completed

# %% [markdown]
# ### Test on cluster

# %% [markdown]
# Convert the code to an MLRun function

# %%
fn = code_to_function('aggregate', 
                      code_output=os.path.join(project_dir, 'src', 'aggregate.py'),
                      kind='job').apply(mount_v3io())
fn.export(os.path.join(project_dir, 'yaml', 'aggregate.yaml'))
# Out:
# [mlrun] 2020-03-12 15:20:52,376 function spec saved to path: /User/demo-network-operations/yaml/aggregate.yaml

# %%
fn.deploy()
# Out:
# [mlrun] 2020-03-12 15:31:39,485 running build to add mlrun package, set with_mlrun=False to skip if its already in the image
# [mlrun] 2020-03-12 15:31:39,486 starting remote build, image: .mlrun/func-default-aggregate-latest
# True

# %%
fn.run(aggregate_task)
# Out:
# [mlrun] 2020-03-12 15:31:40,931 artifact path is not defined or is local,artifacts will not be visible in the UI
# [mlrun] 2020-03-12 15:31:40,931 starting run aggregate uid=94d7854773ee430fb65b47764d4772fb  -> http://mlrun-api:8080
# [mlrun] 2020-03-12 15:31:40,987 Job is running in the background, pod: aggregate-qbft8
# [mlrun] 2020-03-12 15:31:45,693 server (0.4.5) and client (0.4.4) ver dont match
# [mlrun] 2020-03-12 15:31:45,736 server (0.4.5) and client (0.4.4) ver dont match
# [mlrun] 2020-03-12 15:31:45,745 /User/demo-network-operations/data/metrics.pq
# [mlrun] 2020-03-12 15:31:45,876 log artifact aggregate at /User/demo-network-operations/data/aggregate.pq, size: 37175, db: Y
#
# [mlrun] 2020-03-12 15:31:45,885 run executed, status=completed
# final state: succeeded
# <style>
# .dictlist {
#   background-color: #b3edff;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #ffe6cc;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #ffe6cc;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><div title="94d7854773ee430fb65b47764d4772fb">...4772fb</div></td>
#       <td>0</td>
#       <td>Mar 12 15:31:45</td>
#       <td>completed</td>
#       <td>aggregate</td>
#       <td><div class="dictlist">host=aggregate-qbft8</div><div class="dictlist">kind=job</div><div class="dictlist">owner=admin</div></td>
#       <td></td>
#       <td><div class="dictlist">append_to_df=True</div><div class="dictlist">center=True</div><div class="dictlist">df_artifact=/User/demo-network-operations/data/metrics.pq</div><div class="dictlist">label_aggs=['max']</div><div class="dictlist">labels=['is_error']</div><div class="dictlist">metric_aggs=['mean', 'sum']</div><div class="dictlist">metrics=['cpu_utilization']</div><div class="dictlist">save_to=/User/demo-network-operations/data/aggregate.pq</div><div class="dictlist">suffix=daily</div><div class="dictlist">window=5</div></td>
#       <td></td>
#       <td><div title="/User/demo-network-operations/data/aggregate.pq">aggregate</div></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="result7df43313-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="result7df43313-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="result7df43313" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="result7df43313-body"></iframe>
#   </div>
# </div>
# to track results use .show() or .logs() or in CLI:
# !mlrun get run 94d7854773ee430fb65b47764d4772fb --project network-operations , !mlrun logs 94d7854773ee430fb65b47764d4772fb --project network-operations
# [mlrun] 2020-03-12 15:31:47,092 run executed, status=completed

# %%
print(fn.to_yaml())
# Out:
# kind: job
# metadata:
#   name: aggregate
#   tag: ''
#   hash: 142b81f0b4140c847debc791f62b6b6e9f40f328
#   project: ''
#   categories: []
# spec:
#   command: /User/demo-network-operations/src/aggregate.py
#   args: []
#   image: .mlrun/func-default-aggregate-latest
#   volumes:
#   - flexVolume:
#       driver: v3io/fuse
#       options:
#         accessKey: 48bfe2e0-9870-4d11-9924-b20502a85363
#         container: users
#         subPath: /admin
#     name: v3io
#   volume_mounts:
#   - mountPath: /User
#     name: v3io
#   env:
#   - name: V3IO_API
#     value: v3io-webapi.default-tenant.svc:8081
#   - name: V3IO_USERNAME
#     value: admin
#   - name: V3IO_ACCESS_KEY
#     value: 48bfe2e0-9870-4d11-9924-b20502a85363
#   description: ''
#   build:
#     image: .mlrun/func-default-aggregate-latest
#     commands: []
#     code_origin: http://github.com/zilbermanor/demo-network-operations#22e21274be22a767435c8f3dd21169d8912e99cc:aggregate.ipynb
# status:
#   state: ready
#   build_pod: ''

# %% [markdown]
# ### Show results

# %%
df = pd.read_parquet('../data/metrics.pq')

# %%
df.rolling(window=5, center=True).sum()
# Out:
#                                                                                         cpu_utilization  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526              NaN
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526              NaN
# 2020-03-10 08:52:47.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526       355.621234
# 2020-03-10 08:52:52.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526       360.114513
# 2020-03-10 08:52:57.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526       384.055156
# ...                                                                                                 ...
# 2020-03-10 08:57:57.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721       335.951869
# 2020-03-10 08:58:02.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721       342.293920
# 2020-03-10 08:58:07.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721       337.549788
# 2020-03-10 08:58:12.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721              NaN
# 2020-03-10 08:58:17.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721              NaN
#
#                                                                                         cpu_utilization_is_error  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                       NaN
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                       NaN
# 2020-03-10 08:52:47.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                       0.0
# 2020-03-10 08:52:52.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                       0.0
# 2020-03-10 08:52:57.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                       0.0
# ...                                                                                                          ...
# 2020-03-10 08:57:57.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                       0.0
# 2020-03-10 08:58:02.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                       0.0
# 2020-03-10 08:58:07.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                       0.0
# 2020-03-10 08:58:12.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                       NaN
# 2020-03-10 08:58:17.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                       NaN
#
#                                                                                         is_error  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526       NaN
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526       NaN
# 2020-03-10 08:52:47.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526       0.0
# 2020-03-10 08:52:52.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526       0.0
# 2020-03-10 08:52:57.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526       0.0
# ...                                                                                          ...
# 2020-03-10 08:57:57.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721       0.0
# 2020-03-10 08:58:02.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721       0.0
# 2020-03-10 08:58:07.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721       0.0
# 2020-03-10 08:58:12.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721       NaN
# 2020-03-10 08:58:17.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721       NaN
#
#                                                                                           latency  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526        NaN
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526        NaN
# 2020-03-10 08:52:47.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  12.542095
# 2020-03-10 08:52:52.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  16.670036
# 2020-03-10 08:52:57.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  16.670036
# ...                                                                                           ...
# 2020-03-10 08:57:57.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721  21.039117
# 2020-03-10 08:58:02.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721  23.681274
# 2020-03-10 08:58:07.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721  18.354520
# 2020-03-10 08:58:12.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721        NaN
# 2020-03-10 08:58:17.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721        NaN
#
#                                                                                         latency_is_error  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526               NaN
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526               NaN
# 2020-03-10 08:52:47.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526               0.0
# 2020-03-10 08:52:52.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526               0.0
# 2020-03-10 08:52:57.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526               0.0
# ...                                                                                                  ...
# 2020-03-10 08:57:57.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721               0.0
# 2020-03-10 08:58:02.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721               0.0
# 2020-03-10 08:58:07.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721               0.0
# 2020-03-10 08:58:12.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721               NaN
# 2020-03-10 08:58:17.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721               NaN
#
#                                                                                         packet_loss  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526          NaN
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526          NaN
# 2020-03-10 08:52:47.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526     2.573906
# 2020-03-10 08:52:52.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526     2.710323
# 2020-03-10 08:52:57.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526     2.597040
# ...                                                                                             ...
# 2020-03-10 08:57:57.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721     2.213513
# 2020-03-10 08:58:02.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721     3.610201
# 2020-03-10 08:58:07.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721     2.057471
# 2020-03-10 08:58:12.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721          NaN
# 2020-03-10 08:58:17.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721          NaN
#
#                                                                                         packet_loss_is_error  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                   NaN
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                   NaN
# 2020-03-10 08:52:47.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                   0.0
# 2020-03-10 08:52:52.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                   0.0
# 2020-03-10 08:52:57.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                   0.0
# ...                                                                                                      ...
# 2020-03-10 08:57:57.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                   0.0
# 2020-03-10 08:58:02.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                   0.0
# 2020-03-10 08:58:07.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                   0.0
# 2020-03-10 08:58:12.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                   NaN
# 2020-03-10 08:58:17.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                   NaN
#
#                                                                                          throughput  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526          NaN
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526          NaN
# 2020-03-10 08:52:47.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  1283.408906
# 2020-03-10 08:52:52.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  1277.847154
# 2020-03-10 08:52:57.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  1270.497754
# ...                                                                                             ...
# 2020-03-10 08:57:57.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721  1144.925182
# 2020-03-10 08:58:02.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721  1159.025662
# 2020-03-10 08:58:07.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721  1208.098993
# 2020-03-10 08:58:12.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721          NaN
# 2020-03-10 08:58:17.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721          NaN
#
#                                                                                         throughput_is_error
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                  NaN
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                  NaN
# 2020-03-10 08:52:47.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                  0.0
# 2020-03-10 08:52:52.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                  0.0
# 2020-03-10 08:52:57.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                  0.0
# ...                                                                                                     ...
# 2020-03-10 08:57:57.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                  0.0
# 2020-03-10 08:58:02.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                  0.0
# 2020-03-10 08:58:07.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                  0.0
# 2020-03-10 08:58:12.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                  NaN
# 2020-03-10 08:58:17.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                  NaN
#
# [552 rows x 9 columns]

# %%
pd.read_parquet(os.path.join('/User/demo-network-operations', 'data', 'aggregate.pq'))
# Out:
#                                                                                         cpu_utilization  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526        78.396905
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526        73.343463
# 2020-03-10 08:52:47.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526        59.492871
# 2020-03-10 08:52:52.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526        73.483893
# 2020-03-10 08:52:57.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526        70.904103
# ...                                                                                                 ...
# 2020-03-10 08:57:57.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721        66.094782
# 2020-03-10 08:58:02.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721        60.035049
# 2020-03-10 08:58:07.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721        68.830267
# 2020-03-10 08:58:12.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721        79.060649
# 2020-03-10 08:58:17.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721        63.529042
#
#                                                                                         cpu_utilization_is_error  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                       0.0
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                       0.0
# 2020-03-10 08:52:47.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                       0.0
# 2020-03-10 08:52:52.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                       0.0
# 2020-03-10 08:52:57.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                       0.0
# ...                                                                                                          ...
# 2020-03-10 08:57:57.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                       0.0
# 2020-03-10 08:58:02.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                       0.0
# 2020-03-10 08:58:07.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                       0.0
# 2020-03-10 08:58:12.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                       0.0
# 2020-03-10 08:58:17.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                       0.0
#
#                                                                                         is_error  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526       0.0
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526       0.0
# 2020-03-10 08:52:47.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526       0.0
# 2020-03-10 08:52:52.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526       0.0
# 2020-03-10 08:52:57.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526       0.0
# ...                                                                                          ...
# 2020-03-10 08:57:57.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721       0.0
# 2020-03-10 08:58:02.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721       0.0
# 2020-03-10 08:58:07.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721       0.0
# 2020-03-10 08:58:12.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721       0.0
# 2020-03-10 08:58:17.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721       0.0
#
#                                                                                          latency  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  0.000000
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  0.000000
# 2020-03-10 08:52:47.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  0.000000
# 2020-03-10 08:52:52.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  3.051355
# 2020-03-10 08:52:57.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  9.490740
# ...                                                                                          ...
# 2020-03-10 08:57:57.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721  3.251496
# 2020-03-10 08:58:02.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721  5.759561
# 2020-03-10 08:58:07.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721  4.006027
# 2020-03-10 08:58:12.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721  2.929080
# 2020-03-10 08:58:17.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721  2.408355
#
#                                                                                         latency_is_error  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526               0.0
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526               0.0
# 2020-03-10 08:52:47.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526               0.0
# 2020-03-10 08:52:52.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526               0.0
# 2020-03-10 08:52:57.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526               0.0
# ...                                                                                                  ...
# 2020-03-10 08:57:57.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721               0.0
# 2020-03-10 08:58:02.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721               0.0
# 2020-03-10 08:58:07.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721               0.0
# 2020-03-10 08:58:12.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721               0.0
# 2020-03-10 08:58:17.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721               0.0
#
#                                                                                         packet_loss  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526     0.000000
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526     0.113283
# 2020-03-10 08:52:47.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526     2.300774
# 2020-03-10 08:52:52.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526     0.000000
# 2020-03-10 08:52:57.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526     0.159850
# ...                                                                                             ...
# 2020-03-10 08:57:57.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721     0.660784
# 2020-03-10 08:58:02.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721     0.000000
# 2020-03-10 08:58:07.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721     0.000000
# 2020-03-10 08:58:12.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721     1.396688
# 2020-03-10 08:58:17.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721     0.000000
#
#                                                                                         packet_loss_is_error  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                   0.0
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                   0.0
# 2020-03-10 08:52:47.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                   0.0
# 2020-03-10 08:52:52.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                   0.0
# 2020-03-10 08:52:57.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                   0.0
# ...                                                                                                      ...
# 2020-03-10 08:57:57.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                   0.0
# 2020-03-10 08:58:02.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                   0.0
# 2020-03-10 08:58:07.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                   0.0
# 2020-03-10 08:58:12.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                   0.0
# 2020-03-10 08:58:17.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                   0.0
#
#                                                                                         throughput  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  251.553131
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  247.769434
# 2020-03-10 08:52:47.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  278.961957
# 2020-03-10 08:52:52.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  240.857938
# 2020-03-10 08:52:57.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526  264.266446
# ...                                                                                            ...
# 2020-03-10 08:57:57.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721  238.154349
# 2020-03-10 08:58:02.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721  244.279546
# 2020-03-10 08:58:07.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721  226.150328
# 2020-03-10 08:58:12.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721  220.933699
# 2020-03-10 08:58:17.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721  278.581072
#
#                                                                                         throughput_is_error  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                  0.0
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                  0.0
# 2020-03-10 08:52:47.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                  0.0
# 2020-03-10 08:52:52.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                  0.0
# 2020-03-10 08:52:57.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                  0.0
# ...                                                                                                     ...
# 2020-03-10 08:57:57.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                  0.0
# 2020-03-10 08:58:02.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                  0.0
# 2020-03-10 08:58:07.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                  0.0
# 2020-03-10 08:58:12.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                  0.0
# 2020-03-10 08:58:17.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                  0.0
#
#                                                                                         cpu_utilization_mean_daily  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                         NaN
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                         NaN
# 2020-03-10 08:52:47.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                   71.124247
# 2020-03-10 08:52:52.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                   72.022903
# 2020-03-10 08:52:57.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                   76.811031
# ...                                                                                                            ...
# 2020-03-10 08:57:57.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                   67.190374
# 2020-03-10 08:58:02.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                   68.458784
# 2020-03-10 08:58:07.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                   67.509958
# 2020-03-10 08:58:12.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                         NaN
# 2020-03-10 08:58:17.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                         NaN
#
#                                                                                         cpu_utilization_sum_daily  \
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                        NaN
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                        NaN
# 2020-03-10 08:52:47.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                 355.621234
# 2020-03-10 08:52:52.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                 360.114513
# 2020-03-10 08:52:57.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                 384.055156
# ...                                                                                                           ...
# 2020-03-10 08:57:57.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                 335.951869
# 2020-03-10 08:58:02.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                 342.293920
# 2020-03-10 08:58:07.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                 337.549788
# 2020-03-10 08:58:12.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                        NaN
# 2020-03-10 08:58:17.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                        NaN
#
#                                                                                         is_error_max_daily
# time                             company                   data_center   device
# 2020-03-10 08:52:37.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                 NaN
# 2020-03-10 08:52:42.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                 NaN
# 2020-03-10 08:52:47.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                 0.0
# 2020-03-10 08:52:52.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                 0.0
# 2020-03-10 08:52:57.874000+00:00 Lambert__Watson_and_Stone Cabrera_Ranch 6767536359526                 0.0
# ...                                                                                                    ...
# 2020-03-10 08:57:57.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                 0.0
# 2020-03-10 08:58:02.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                 0.0
# 2020-03-10 08:58:07.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                 0.0
# 2020-03-10 08:58:12.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                 NaN
# 2020-03-10 08:58:17.874000+00:00 Elliott_Inc               Baldwin_Views 1456313469721                 NaN
#
# [552 rows x 12 columns]
